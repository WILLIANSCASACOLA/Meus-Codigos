# %%
import pandas as pd
import win32com.client as win32
import datetime

# %%
df = pd.read_excel(r'C:\Aplicativos\Meus_Arquivos_Willian\Ambiente_Desenvolvimento\Arquivos_in\Base.xlsx', sheet_name='Planilha2')

# %%
data = datetime.datetime.now().strftime('%d/%m/%Y %H:%M')
print(f'Data {data}')
# Out:
# Data 03/08/2025 17:44

# %%
df.head()  # Display the first few rows of the DataFrame
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase        26196         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...        73194         NaN
# ...

# %%
#Encontrar nome pais
df_pais = df[df['ID_Produto'] == 'OFF-AP-10002311'] #Filtrar DataFrame para incluir apenas linhas onde a coluna 'Segmento' é igual a 'Home Office'
df_pais.head()  # Display the first few rows of the filtered DataFrame
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 1858  CA-2015-121608  2015-09-03   JB-15400    Corporate  United States
# 3140  CA-2015-112557  2015-04-25   JL-15850     Consumer  United States
# 3740  CA-2016-133340  2016-12-09   LH-17155     Consumer  United States
# 5026  US-2017-130953  2017-07-29   RF-19735     Consumer  United States
#
#        Regiao       ID_Produto        Categoria  \
# 14    Central  OFF-AP-10002311  Office Supplies
# 1858     East  OFF-AP-10002311  Office Supplies
# 3140     East  OFF-AP-10002311  Office Supplies
# 3740  Central  OFF-AP-10002311  Office Supplies
# 5026  Central  OFF-AP-10002311  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 14    Holmes Replacement Filter for HEPA Air Cleaner...         6881
# 1858  Holmes Replacement Filter for HEPA Air Cleaner...        13762
# ...

# %%
df_pais.describe()  # Get a statistical summary of the filtered DataFrame
# Out:
#                Data_Pedido    Valor_Venda  Quantidade
# count                   10      10.000000   10.000000
# mean   2016-04-03 07:12:00   63993.300000    2.600000
# min    2014-01-20 00:00:00    6881.000000    1.000000
# 25%    2015-09-20 06:00:00   13762.000000    2.000000
# 50%    2016-03-10 12:00:00   24083.500000    2.000000
# 75%    2016-12-02 06:00:00   98054.250000    3.750000
# max    2017-11-24 00:00:00  247716.000000    5.000000
# std                    NaN   77106.100599    1.349897

# %%
#Filtrar mais de uma segmento
df_segmentos = df[df['Segmento'].isin(['Consumer', 'Corporate'])]
df_segmentos.head(1000)  # Display the first few rows of the filtered DataFrame
# Out:
#            ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0     CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1     CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2     CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3     US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4     US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# ...              ...         ...        ...        ...            ...    ...
# 1210  CA-2016-137050  2016-07-14   SW-20755  Corporate  United States   East
# 1211  CA-2016-137050  2016-07-14   SW-20755  Corporate  United States   East
# 1212  US-2017-118087  2017-09-09   SP-20620  Corporate  United States   East
# 1213  US-2017-118087  2017-09-09   SP-20620  Corporate  United States   East
# 1214  US-2017-118087  2017-09-09   SP-20620  Corporate  United States   East
#
#            ID_Produto        Categoria  \
# ...

# %%
#Exportar para excel
df_segmentos.to_excel(r'C:\Aplicativos\Meus_Arquivos_Willian\Ambiente_Desenvolvimento\Arquivos_in\Segmentos.xlsx', index=False)

# %%
#Abrir o e-mail outlook anexar df_segmentos
import win32com.client as win32
outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)  # Create a new mail item
mail.Subject = f'Base Segmento Atualizado {data}'
mail.Body = f"""Aqui está a base Filtrada com os dados dos segmentos Consumer e Corporate, até as {data}.
Por favor, verifique o arquivo anexado.
Atenciosamente,
Willian Casacola
"""  # Email body text

attachment_path = r'C:\Aplicativos\Meus_Arquivos_Willian\Ambiente_Desenvolvimento\Arquivos_in\Segmentos.xlsx'
mail.Attachments.Add(attachment_path)  # Attach the DataFrame file
mail.To = 'willian.casacola@gmail.com;grascielerobertaviano@gmail.com'  # Specify the recipient's email address
mail.CC = 'grascielerobertaviano@gmail.com'  # Specify CC recipients
mail.Display()  # Display the email for review before sending

print("Email preparado para envio com o arquivo anexado.")  # Confirmation message
# Out:
# Email preparado para envio com o arquivo anexado.
