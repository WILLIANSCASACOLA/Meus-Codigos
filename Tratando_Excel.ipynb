# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Aplicativos\Meus_Arquivos_Willian\Ambiente_Desenvolvimento\Arquivos_in\Clientes.csv', delimiter=',', encoding='utf-8')

# %%
df.head(20)  # Display the first few rows of the DataFrame

# %%
#Substituir valores
df['street']        = df['street'].fillna('Rua sem Nome')
df['email']         = df['email'].fillna('Sem e-mail')
df['number']        = df['number'].fillna(0)
df['additionals']   = df['additionals'].fillna('Sem Adicionais')
df.head(20)

# %% [markdown]
# # Substituindo valores com replace

# %%
df = pd.read_csv(r'C:\Aplicativos\Meus_Arquivos_Willian\Ambiente_Desenvolvimento\Arquivos_in\Clientes.csv', delimiter=',', encoding='utf-8')
df

# %%
# Substituindo valores com replace
df['state'] = df['state'].replace('São Paulo', 'Sao Paulo')
df.head(20)

# %%
#Substituindo valores também com variáveis
estado_antigo = 'Sao Paulo'
estado_novo = 'SP'
df['state'] = df['state'].replace(estado_antigo, estado_novo)
df.head(20)

# %%
df = pd.read_csv(r'C:\Aplicativos\Meus_Arquivos_Willian\Ambiente_Desenvolvimento\Arquivos_in\Clientes.csv', delimiter=',', encoding='utf-8')
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
#Mapear os nomes dos estados para susbtituição
estados = {
    'São Paulo': 'SP',
    'Rio de Janeiro': 'RJ',
    'Minas Gerais': 'MG',
    'Bahia': 'BA',
    'Rio Grande do Sul': 'RS',
}
# Substituindo valores com map
df['state'] = df['state'].replace(estados)
df.head(500)
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country        state                                  street  \
# ...
