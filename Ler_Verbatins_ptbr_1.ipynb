# %% [markdown]
# <a href="https://colab.research.google.com/github/WILLIANSCASACOLA/Meus-Codigos/blob/main/Ler_Verbatins_ptbr_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline
import pandas as pd
import torch

# %%
# Verifica se há GPU disponível
device = 0 if torch.cuda.is_available() else -1

# %%
# Carrega pipeline com modelo multilíngue
analisador = pipeline("sentiment-analysis",
                      model="nlptown/bert-base-multilingual-uncased-sentiment",
                      device=device)
# Out:
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Device set to use cpu

# %%
# Lê os comentários
df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Arquivos_Ler/Verbatins.xlsx")

# %%
df.head(10)
# Out:
#    ID         Nome       Data       aaa  \
# 0   1       Ana P. 2024-08-14  Positivo
# 1   2    Carlos M. 2024-11-03  Negativo
# 2   3   Juliana R. 2025-01-22  Positivo
# 3   4    Marcos T. 2024-07-09  Negativo
# 4   5    Renata L. 2025-03-18  Negativo
# 5   6    Felipe S. 2024-10-27  Positivo
# 6   7   Luciana D. 2024-12-05    Neutro
# 7   8     Bruno C. 2025-02-11  Positivo
# 8   9  Patrícia V. 2024-09-30  Negativo
# 9  10    Thiago N. 2025-04-02  Positivo
#
#                                           Comentário
# 0  O atendimento foi excelente, resolveram meu pr...
# 1  Demora demais para aprovar o limite, muito bur...
# 2  Gosto bastante do app, é fácil de usar e bem i...
# 3  Cobram muitas taxas escondidas, fiquei decepci...
# 4  Atendimento pelo chat foi péssimo, demoraram h...
# 5  Consegui vários descontos no crédito rotativo,...
# 6          O cartão é bom, mas o app trava bastante.
# 7  Me surpreendi com os benefícios que o cartão o...
# 8  Não consigo acessar minha fatura há dias, absu...
# 9  Amo o programa de pontos, já troquei por duas ...

# %%
# Função para aplicar análise
def analisar_sentimento(texto):
    resultado = analisador(str(texto))[0]
    label = resultado['label']
    score = resultado['score']

    # Converte label para categoria
    estrelas = int(label[0])
    if estrelas <= 2:
        categoria = "Negativo"
    elif estrelas == 3:
        categoria = "Neutro"
    else:
        categoria = "Positivo"

    return pd.Series([label, score, categoria])

# %%
# Aplica ao DataFrame
df[["Label_Modelo", "Confianca", "Categoria"]] = df["Comentário"].apply(analisar_sentimento)

# %%
df.head(10)
# Out:
#    ID         Nome       Data       aaa  \
# 0   1       Ana P. 2024-08-14  Positivo
# 1   2    Carlos M. 2024-11-03  Negativo
# 2   3   Juliana R. 2025-01-22  Positivo
# 3   4    Marcos T. 2024-07-09  Negativo
# 4   5    Renata L. 2025-03-18  Negativo
# 5   6    Felipe S. 2024-10-27  Positivo
# 6   7   Luciana D. 2024-12-05    Neutro
# 7   8     Bruno C. 2025-02-11  Positivo
# 8   9  Patrícia V. 2024-09-30  Negativo
# 9  10    Thiago N. 2025-04-02  Positivo
#
#                                           Comentário Label_Modelo  Confianca  \
# 0  O atendimento foi excelente, resolveram meu pr...      5 stars   0.553561
# 1  Demora demais para aprovar o limite, muito bur...      2 stars   0.462444
# 2  Gosto bastante do app, é fácil de usar e bem i...      4 stars   0.513934
# 3  Cobram muitas taxas escondidas, fiquei decepci...       1 star   0.581100
# 4  Atendimento pelo chat foi péssimo, demoraram h...       1 star   0.625148
# 5  Consegui vários descontos no crédito rotativo,...      4 stars   0.439305
# 6          O cartão é bom, mas o app trava bastante.      3 stars   0.651369
# 7  Me surpreendi com os benefícios que o cartão o...      5 stars   0.500487
# 8  Não consigo acessar minha fatura há dias, absu...       1 star   0.864590
# 9  Amo o programa de pontos, já troquei por duas ...      5 stars   0.377436
#
#   Categoria
# 0  Positivo
# 1  Negativo
# 2  Positivo
# 3  Negativo
# 4  Negativo
# 5  Positivo
# 6    Neutro
# 7  Positivo
# 8  Negativo
# 9  Positivo

# %%
# Exportar o resultado
df.to_csv("/content/drive/MyDrive/Colab Notebooks/Arquivos_Ler/comentarios_analisados_vader.csv", index=False)
